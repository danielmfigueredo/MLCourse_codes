# %%
# %matplotlib inline
import numpy as np
import pandas as pd
col = ['BI_RADS','age','shape', 'margin', 'density', 'severity']
df = pd.read_csv("mammographic_masses.data.txt", names=col, header=None, na_values={'BI_RADS':'?','age':'?','shape':'?', 'margin':'?', 'density':'?', 'severity':'?'})
df.head()
# Out:
#    BI_RADS   age  shape  margin  density  severity
# 0      5.0  67.0    3.0     5.0      3.0         1
# 1      4.0  43.0    1.0     1.0      NaN         1
# 2      5.0  58.0    4.0     5.0      3.0         1
# 3      4.0  28.0    1.0     1.0      3.0         0
# 4      5.0  74.0    1.0     5.0      NaN         1

# %%
df = df.dropna()
features = ['age', 'shape', 'margin','density']
classes = 'severity'
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df[features], df[classes], test_size=0.25, random_state=0)

from sklearn.preprocessing import StandardScaler
x = X_train.values
g = X_test.values
scaler = StandardScaler()
scaled = scaler.fit_transform(x)
X_train = pd.DataFrame(scaled)
scaled = scaler.fit_transform(g)
X_test = pd.DataFrame(scaled)

# %%
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(4,)))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu', input_shape=(20,)))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu', input_shape=(20,)))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 32)                160
#
#  dropout_18 (Dropout)        (None, 32)                0
#
#  dense_29 (Dense)            (None, 32)                1056
#
#  dropout_19 (Dropout)        (None, 32)                0
#
#  dense_30 (Dense)            (None, 32)                1056
#
#  dropout_20 (Dropout)        (None, 32)                0
#
#  dense_31 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 2,305
# Trainable params: 2,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values
history = model.fit(X_train, y_train,
                    batch_size=100,
                    epochs=100,
                    verbose=2,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 7/7 - 1s - loss: 0.6624 - accuracy: 0.5643 - val_loss: 0.6206 - val_accuracy: 0.7837 - 834ms/epoch - 119ms/step
# Epoch 2/100
# 7/7 - 0s - loss: 0.6041 - accuracy: 0.7444 - val_loss: 0.5712 - val_accuracy: 0.7837 - 134ms/epoch - 19ms/step
# Epoch 3/100
# 7/7 - 0s - loss: 0.5580 - accuracy: 0.7862 - val_loss: 0.5322 - val_accuracy: 0.7788 - 133ms/epoch - 19ms/step
# Epoch 4/100
# 7/7 - 0s - loss: 0.5222 - accuracy: 0.7894 - val_loss: 0.5016 - val_accuracy: 0.7885 - 135ms/epoch - 19ms/step
# Epoch 5/100
# 7/7 - 0s - loss: 0.5067 - accuracy: 0.7926 - val_loss: 0.4840 - val_accuracy: 0.7885 - 89ms/epoch - 13ms/step
# Epoch 6/100
# 7/7 - 0s - loss: 0.4865 - accuracy: 0.8055 - val_loss: 0.4737 - val_accuracy: 0.7885 - 109ms/epoch - 16ms/step
# Epoch 7/100
# 7/7 - 0s - loss: 0.4826 - accuracy: 0.7974 - val_loss: 0.4696 - val_accuracy: 0.7837 - 82ms/epoch - 12ms/step
# Epoch 8/100
# 7/7 - 0s - loss: 0.4730 - accuracy: 0.8023 - val_loss: 0.4684 - val_accuracy: 0.7837 - 54ms/epoch - 8ms/step
# Epoch 9/100
# 7/7 - 0s - loss: 0.4706 - accuracy: 0.7990 - val_loss: 0.4681 - val_accuracy: 0.7885 - 72ms/epoch - 10ms/step
# Epoch 10/100
# 7/7 - 0s - loss: 0.4591 - accuracy: 0.8103 - val_loss: 0.4686 - val_accuracy: 0.7788 - 77ms/epoch - 11ms/step
# Epoch 11/100
# 7/7 - 0s - loss: 0.4543 - accuracy: 0.8006 - val_loss: 0.4694 - val_accuracy: 0.7788 - 126ms/epoch - 18ms/step
# Epoch 12/100
# 7/7 - 0s - loss: 0.4559 - accuracy: 0.7958 - val_loss: 0.4717 - val_accuracy: 0.7788 - 133ms/epoch - 19ms/step
# Epoch 13/100
# 7/7 - 0s - loss: 0.4641 - accuracy: 0.8006 - val_loss: 0.4705 - val_accuracy: 0.7885 - 107ms/epoch - 15ms/step
# Epoch 14/100
# 7/7 - 0s - loss: 0.4626 - accuracy: 0.7958 - val_loss: 0.4724 - val_accuracy: 0.7788 - 107ms/epoch - 15ms/step
# Epoch 15/100
# 7/7 - 0s - loss: 0.4751 - accuracy: 0.7990 - val_loss: 0.4718 - val_accuracy: 0.7788 - 111ms/epoch - 16ms/step
# Epoch 16/100
# 7/7 - 0s - loss: 0.4654 - accuracy: 0.8023 - val_loss: 0.4724 - val_accuracy: 0.7885 - 111ms/epoch - 16ms/step
# Epoch 17/100
# 7/7 - 0s - loss: 0.4500 - accuracy: 0.8039 - val_loss: 0.4732 - val_accuracy: 0.7885 - 106ms/epoch - 15ms/step
# Epoch 18/100
# 7/7 - 0s - loss: 0.4626 - accuracy: 0.8055 - val_loss: 0.4728 - val_accuracy: 0.7885 - 107ms/epoch - 15ms/step
# Epoch 19/100
# 7/7 - 0s - loss: 0.4509 - accuracy: 0.8039 - val_loss: 0.4743 - val_accuracy: 0.7885 - 80ms/epoch - 11ms/step
# Epoch 20/100
# 7/7 - 0s - loss: 0.4528 - accuracy: 0.7974 - val_loss: 0.4752 - val_accuracy: 0.7933 - 116ms/epoch - 17ms/step
# Epoch 21/100
# 7/7 - 0s - loss: 0.4610 - accuracy: 0.8023 - val_loss: 0.4731 - val_accuracy: 0.7885 - 108ms/epoch - 15ms/step
# Epoch 22/100
# 7/7 - 0s - loss: 0.4518 - accuracy: 0.7958 - val_loss: 0.4731 - val_accuracy: 0.7885 - 110ms/epoch - 16ms/step
# Epoch 23/100
# 7/7 - 0s - loss: 0.4617 - accuracy: 0.7990 - val_loss: 0.4739 - val_accuracy: 0.7885 - 114ms/epoch - 16ms/step
# Epoch 24/100
# 7/7 - 0s - loss: 0.4545 - accuracy: 0.8039 - val_loss: 0.4736 - val_accuracy: 0.7885 - 86ms/epoch - 12ms/step
# Epoch 25/100
# 7/7 - 0s - loss: 0.4536 - accuracy: 0.8151 - val_loss: 0.4742 - val_accuracy: 0.7933 - 102ms/epoch - 15ms/step
# Epoch 26/100
# 7/7 - 0s - loss: 0.4575 - accuracy: 0.7958 - val_loss: 0.4739 - val_accuracy: 0.7933 - 96ms/epoch - 14ms/step
# Epoch 27/100
# 7/7 - 0s - loss: 0.4522 - accuracy: 0.8087 - val_loss: 0.4730 - val_accuracy: 0.7933 - 116ms/epoch - 17ms/step
# Epoch 28/100
# 7/7 - 0s - loss: 0.4583 - accuracy: 0.8071 - val_loss: 0.4744 - val_accuracy: 0.7933 - 110ms/epoch - 16ms/step
# Epoch 29/100
# 7/7 - 0s - loss: 0.4556 - accuracy: 0.8023 - val_loss: 0.4747 - val_accuracy: 0.7981 - 77ms/epoch - 11ms/step
# Epoch 30/100
# 7/7 - 0s - loss: 0.4603 - accuracy: 0.8006 - val_loss: 0.4748 - val_accuracy: 0.7885 - 122ms/epoch - 17ms/step
# Epoch 31/100
# 7/7 - 0s - loss: 0.4307 - accuracy: 0.8087 - val_loss: 0.4755 - val_accuracy: 0.7885 - 98ms/epoch - 14ms/step
# Epoch 32/100
# 7/7 - 0s - loss: 0.4543 - accuracy: 0.8087 - val_loss: 0.4756 - val_accuracy: 0.7885 - 133ms/epoch - 19ms/step
# Epoch 33/100
# 7/7 - 0s - loss: 0.4601 - accuracy: 0.8023 - val_loss: 0.4740 - val_accuracy: 0.7885 - 125ms/epoch - 18ms/step
# Epoch 34/100
# 7/7 - 0s - loss: 0.4311 - accuracy: 0.8151 - val_loss: 0.4757 - val_accuracy: 0.7885 - 106ms/epoch - 15ms/step
# Epoch 35/100
# 7/7 - 0s - loss: 0.4547 - accuracy: 0.8103 - val_loss: 0.4762 - val_accuracy: 0.7933 - 106ms/epoch - 15ms/step
# Epoch 36/100
# 7/7 - 0s - loss: 0.4502 - accuracy: 0.8183 - val_loss: 0.4770 - val_accuracy: 0.7933 - 98ms/epoch - 14ms/step
# Epoch 37/100
# 7/7 - 0s - loss: 0.4354 - accuracy: 0.8135 - val_loss: 0.4774 - val_accuracy: 0.7933 - 102ms/epoch - 15ms/step
# Epoch 38/100
# 7/7 - 0s - loss: 0.4453 - accuracy: 0.8199 - val_loss: 0.4778 - val_accuracy: 0.7981 - 119ms/epoch - 17ms/step
# Epoch 39/100
# 7/7 - 0s - loss: 0.4456 - accuracy: 0.8039 - val_loss: 0.4763 - val_accuracy: 0.7933 - 97ms/epoch - 14ms/step
# Epoch 40/100
# 7/7 - 0s - loss: 0.4552 - accuracy: 0.8135 - val_loss: 0.4753 - val_accuracy: 0.7981 - 99ms/epoch - 14ms/step
# Epoch 41/100
# 7/7 - 0s - loss: 0.4429 - accuracy: 0.8103 - val_loss: 0.4756 - val_accuracy: 0.7933 - 121ms/epoch - 17ms/step
# Epoch 42/100
# 7/7 - 0s - loss: 0.4440 - accuracy: 0.8103 - val_loss: 0.4770 - val_accuracy: 0.7933 - 103ms/epoch - 15ms/step
# Epoch 43/100
# 7/7 - 0s - loss: 0.4603 - accuracy: 0.8119 - val_loss: 0.4774 - val_accuracy: 0.7933 - 93ms/epoch - 13ms/step
# Epoch 44/100
# 7/7 - 0s - loss: 0.4483 - accuracy: 0.8167 - val_loss: 0.4769 - val_accuracy: 0.7981 - 92ms/epoch - 13ms/step
# Epoch 45/100
# 7/7 - 0s - loss: 0.4382 - accuracy: 0.8119 - val_loss: 0.4772 - val_accuracy: 0.7933 - 88ms/epoch - 13ms/step
# Epoch 46/100
# 7/7 - 0s - loss: 0.4446 - accuracy: 0.8071 - val_loss: 0.4768 - val_accuracy: 0.7933 - 101ms/epoch - 14ms/step
# Epoch 47/100
# 7/7 - 0s - loss: 0.4376 - accuracy: 0.8071 - val_loss: 0.4785 - val_accuracy: 0.7981 - 96ms/epoch - 14ms/step
# Epoch 48/100
# 7/7 - 0s - loss: 0.4361 - accuracy: 0.8119 - val_loss: 0.4777 - val_accuracy: 0.7933 - 108ms/epoch - 15ms/step
# Epoch 49/100
# 7/7 - 0s - loss: 0.4517 - accuracy: 0.8023 - val_loss: 0.4781 - val_accuracy: 0.7981 - 100ms/epoch - 14ms/step
# Epoch 50/100
# 7/7 - 0s - loss: 0.4326 - accuracy: 0.8119 - val_loss: 0.4793 - val_accuracy: 0.7981 - 97ms/epoch - 14ms/step
# Epoch 51/100
# 7/7 - 0s - loss: 0.4453 - accuracy: 0.8071 - val_loss: 0.4790 - val_accuracy: 0.7981 - 115ms/epoch - 16ms/step
# Epoch 52/100
# 7/7 - 0s - loss: 0.4586 - accuracy: 0.8119 - val_loss: 0.4774 - val_accuracy: 0.7981 - 97ms/epoch - 14ms/step
# Epoch 53/100
# 7/7 - 0s - loss: 0.4374 - accuracy: 0.8135 - val_loss: 0.4769 - val_accuracy: 0.7981 - 104ms/epoch - 15ms/step
# Epoch 54/100
# 7/7 - 0s - loss: 0.4455 - accuracy: 0.8055 - val_loss: 0.4757 - val_accuracy: 0.7981 - 109ms/epoch - 16ms/step
# Epoch 55/100
# 7/7 - 0s - loss: 0.4430 - accuracy: 0.8167 - val_loss: 0.4759 - val_accuracy: 0.7981 - 99ms/epoch - 14ms/step
# Epoch 56/100
# 7/7 - 0s - loss: 0.4458 - accuracy: 0.8151 - val_loss: 0.4785 - val_accuracy: 0.7981 - 101ms/epoch - 14ms/step
# Epoch 57/100
# 7/7 - 0s - loss: 0.4325 - accuracy: 0.8199 - val_loss: 0.4790 - val_accuracy: 0.7981 - 96ms/epoch - 14ms/step
# Epoch 58/100
# 7/7 - 0s - loss: 0.4397 - accuracy: 0.8199 - val_loss: 0.4773 - val_accuracy: 0.7981 - 118ms/epoch - 17ms/step
# Epoch 59/100
# 7/7 - 0s - loss: 0.4390 - accuracy: 0.8151 - val_loss: 0.4765 - val_accuracy: 0.7981 - 116ms/epoch - 17ms/step
# Epoch 60/100
# 7/7 - 0s - loss: 0.4315 - accuracy: 0.8151 - val_loss: 0.4767 - val_accuracy: 0.7981 - 97ms/epoch - 14ms/step
# Epoch 61/100
# 7/7 - 0s - loss: 0.4387 - accuracy: 0.8135 - val_loss: 0.4786 - val_accuracy: 0.7981 - 98ms/epoch - 14ms/step
# Epoch 62/100
# 7/7 - 0s - loss: 0.4443 - accuracy: 0.8183 - val_loss: 0.4786 - val_accuracy: 0.7981 - 130ms/epoch - 19ms/step
# Epoch 63/100
# 7/7 - 0s - loss: 0.4433 - accuracy: 0.8151 - val_loss: 0.4805 - val_accuracy: 0.7981 - 106ms/epoch - 15ms/step
# Epoch 64/100
# 7/7 - 0s - loss: 0.4390 - accuracy: 0.8071 - val_loss: 0.4813 - val_accuracy: 0.7981 - 70ms/epoch - 10ms/step
# Epoch 65/100
# 7/7 - 0s - loss: 0.4502 - accuracy: 0.8151 - val_loss: 0.4801 - val_accuracy: 0.7981 - 83ms/epoch - 12ms/step
# Epoch 66/100
# 7/7 - 0s - loss: 0.4326 - accuracy: 0.8167 - val_loss: 0.4817 - val_accuracy: 0.7981 - 87ms/epoch - 12ms/step
# Epoch 67/100
# 7/7 - 0s - loss: 0.4314 - accuracy: 0.8167 - val_loss: 0.4825 - val_accuracy: 0.7981 - 133ms/epoch - 19ms/step
# Epoch 68/100
# 7/7 - 0s - loss: 0.4455 - accuracy: 0.8103 - val_loss: 0.4821 - val_accuracy: 0.7981 - 88ms/epoch - 13ms/step
# Epoch 69/100
# 7/7 - 0s - loss: 0.4392 - accuracy: 0.8103 - val_loss: 0.4821 - val_accuracy: 0.7981 - 112ms/epoch - 16ms/step
# Epoch 70/100
# 7/7 - 0s - loss: 0.4541 - accuracy: 0.8167 - val_loss: 0.4816 - val_accuracy: 0.7981 - 136ms/epoch - 19ms/step
# Epoch 71/100
# 7/7 - 0s - loss: 0.4428 - accuracy: 0.8119 - val_loss: 0.4800 - val_accuracy: 0.7981 - 123ms/epoch - 18ms/step
# Epoch 72/100
# 7/7 - 0s - loss: 0.4388 - accuracy: 0.8167 - val_loss: 0.4817 - val_accuracy: 0.7981 - 102ms/epoch - 15ms/step
# Epoch 73/100
# 7/7 - 0s - loss: 0.4367 - accuracy: 0.8103 - val_loss: 0.4823 - val_accuracy: 0.7981 - 111ms/epoch - 16ms/step
# Epoch 74/100
# 7/7 - 0s - loss: 0.4475 - accuracy: 0.8135 - val_loss: 0.4822 - val_accuracy: 0.7981 - 130ms/epoch - 19ms/step
# Epoch 75/100
# 7/7 - 0s - loss: 0.4334 - accuracy: 0.8232 - val_loss: 0.4829 - val_accuracy: 0.7981 - 104ms/epoch - 15ms/step
# Epoch 76/100
# 7/7 - 0s - loss: 0.4344 - accuracy: 0.8215 - val_loss: 0.4817 - val_accuracy: 0.7981 - 122ms/epoch - 17ms/step
# Epoch 77/100
# 7/7 - 0s - loss: 0.4312 - accuracy: 0.8151 - val_loss: 0.4813 - val_accuracy: 0.7981 - 126ms/epoch - 18ms/step
# Epoch 78/100
# 7/7 - 0s - loss: 0.4387 - accuracy: 0.8199 - val_loss: 0.4815 - val_accuracy: 0.7981 - 113ms/epoch - 16ms/step
# Epoch 79/100
# 7/7 - 0s - loss: 0.4403 - accuracy: 0.8151 - val_loss: 0.4839 - val_accuracy: 0.7981 - 92ms/epoch - 13ms/step
# Epoch 80/100
# 7/7 - 0s - loss: 0.4491 - accuracy: 0.8167 - val_loss: 0.4843 - val_accuracy: 0.7981 - 112ms/epoch - 16ms/step
# Epoch 81/100
# 7/7 - 0s - loss: 0.4248 - accuracy: 0.8199 - val_loss: 0.4835 - val_accuracy: 0.7981 - 134ms/epoch - 19ms/step
# Epoch 82/100
# 7/7 - 0s - loss: 0.4367 - accuracy: 0.8183 - val_loss: 0.4819 - val_accuracy: 0.7981 - 120ms/epoch - 17ms/step
# Epoch 83/100
# 7/7 - 0s - loss: 0.4468 - accuracy: 0.8055 - val_loss: 0.4841 - val_accuracy: 0.8029 - 97ms/epoch - 14ms/step
# Epoch 84/100
# 7/7 - 0s - loss: 0.4308 - accuracy: 0.8199 - val_loss: 0.4846 - val_accuracy: 0.8029 - 109ms/epoch - 16ms/step
# Epoch 85/100
# 7/7 - 0s - loss: 0.4377 - accuracy: 0.8183 - val_loss: 0.4856 - val_accuracy: 0.7981 - 124ms/epoch - 18ms/step
# Epoch 86/100
# 7/7 - 0s - loss: 0.4409 - accuracy: 0.8135 - val_loss: 0.4839 - val_accuracy: 0.8029 - 126ms/epoch - 18ms/step
# Epoch 87/100
# 7/7 - 0s - loss: 0.4379 - accuracy: 0.8199 - val_loss: 0.4831 - val_accuracy: 0.8029 - 94ms/epoch - 13ms/step
# Epoch 88/100
# 7/7 - 0s - loss: 0.4330 - accuracy: 0.8167 - val_loss: 0.4846 - val_accuracy: 0.8029 - 142ms/epoch - 20ms/step
# Epoch 89/100
# 7/7 - 0s - loss: 0.4383 - accuracy: 0.8151 - val_loss: 0.4842 - val_accuracy: 0.8029 - 97ms/epoch - 14ms/step
# Epoch 90/100
# 7/7 - 0s - loss: 0.4276 - accuracy: 0.8167 - val_loss: 0.4867 - val_accuracy: 0.8029 - 105ms/epoch - 15ms/step
# Epoch 91/100
# 7/7 - 0s - loss: 0.4368 - accuracy: 0.8183 - val_loss: 0.4885 - val_accuracy: 0.8029 - 128ms/epoch - 18ms/step
# Epoch 92/100
# 7/7 - 0s - loss: 0.4276 - accuracy: 0.8199 - val_loss: 0.4848 - val_accuracy: 0.8029 - 125ms/epoch - 18ms/step
# Epoch 93/100
# 7/7 - 0s - loss: 0.4386 - accuracy: 0.8167 - val_loss: 0.4862 - val_accuracy: 0.8029 - 114ms/epoch - 16ms/step
# Epoch 94/100
# 7/7 - 0s - loss: 0.4296 - accuracy: 0.8183 - val_loss: 0.4839 - val_accuracy: 0.8029 - 96ms/epoch - 14ms/step
# Epoch 95/100
# 7/7 - 0s - loss: 0.4301 - accuracy: 0.8167 - val_loss: 0.4844 - val_accuracy: 0.8029 - 135ms/epoch - 19ms/step
# Epoch 96/100
# 7/7 - 0s - loss: 0.4304 - accuracy: 0.8232 - val_loss: 0.4845 - val_accuracy: 0.8029 - 106ms/epoch - 15ms/step
# Epoch 97/100
# 7/7 - 0s - loss: 0.4314 - accuracy: 0.8215 - val_loss: 0.4826 - val_accuracy: 0.8029 - 89ms/epoch - 13ms/step
# Epoch 98/100
# 7/7 - 0s - loss: 0.4374 - accuracy: 0.8087 - val_loss: 0.4824 - val_accuracy: 0.8029 - 99ms/epoch - 14ms/step
# Epoch 99/100
# 7/7 - 0s - loss: 0.4426 - accuracy: 0.8055 - val_loss: 0.4841 - val_accuracy: 0.8029 - 106ms/epoch - 15ms/step
# Epoch 100/100
# 7/7 - 0s - loss: 0.4447 - accuracy: 0.8135 - val_loss: 0.4840 - val_accuracy: 0.8029 - 91ms/epoch - 13ms/step
